# %% [markdown]
# # Example 1: Trump v Clinton

# %% [markdown]
# Open debate_transcript.txt

# %%
with open('debate_transcript.txt') as file:
    text = file.read()

# %% [markdown]
# Parse and filter the transcript

# %%
transcript = text.split('\n\n')

# %%
filtered_transcript = []
for para in transcript:
    if para.startswith('Trump:'):
        filtered_transcript.append((0,para[7:]))
    elif para.startswith('Clinton:'):
        filtered_transcript.append((1,para[9:]))

# %% [markdown]
# Import the module

# %%
import sys, os

# %%
package_path = os.path.dirname(os.getcwd())
sys.path.append(package_path)

# %%
from wordmesh import Wordmesh, LabelledWordmesh

# %% [markdown]
# Create a LabelledWordmesh object, and extract the **40 most frequently used *adjectives*** for each label

# %%
wm = LabelledWordmesh(filtered_transcript, num_keywords=40, extract_ngrams=False, 
                      keyword_extractor='tf', pos_filter=['ADJ'])

# %% [markdown]
# Cluster the extracted keywords on the canvas based on their **meaning**

# %%
wm.set_clustering_criteria(by='meaning')

# %% [markdown]
# Color the keywords based on their label

# %%
colormap = lambda x: (250,100,150) if (x==0) else (150,100,250)
wm.set_fontcolor(custom_colors = list(map(colormap, wm.labels)))

# %%
wm.save_as_html(force_directed_animation=False, notebook_mode=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="e482be26-e784-4556-a62d-53bdc2b97009" style="height: 500px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'e482be26-e784-4556-a62d-53bdc2b97009',
#             [{"type": "scatter", "hoverinfo": "skip", "hovertext": null, "showlegend": false, "legendgroup": "default_legend", "name": "default_legend", "x": [-75.84146998138468, 113.27313253678236, -188.55569774968708, -140.05625488311765, -179.37363664724833, -41.18827978239736, 8.57740632611323, -90.74344563890412, 63.83188016676293, -212.6239522873758, 255.37219549477854, -106.09515735053739, -22.4750864429792, 85.3024001254677, -24.993856318216547, -54.26275753423488, -124.27599860887048, 129.67051922150566, 118.61779161100435, -78.75167291060967, -18.18499390000537, -35.187192974190864, 46.50344732123159, -57.60301199253437, 10.097087372172805, 47.294350399150886, 66.05008943281919, -267.99649071830135, 69.17271169695306, -8.585927576975106, -174.0273188274296, 133.93205587425527, 140.64276421835015, 17.548042224005165, 85.51778317880856, -164.8382357263544, 125.01101210140092, -62.704649133434266, 45.7376224217456, -112.11223154738434, -181.04578629404446, 23.418358163755926, -53.52785499911526, -98.16359717558431, 236.8886840188691, -44.62028117111191, 31.197691980341858, -85.18833448094, -81.5079055391297, -185.21425668807817, -151.58482541670486, 153.23067076565093, -142.67485072795284, 6.55971558723434, -7.658985589165342, 60.83963641332245, -164.01440285980865, 15.770188662544086, -104.2667997475486, 34.