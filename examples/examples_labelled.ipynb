# %% [markdown]
# # Example 1: Trump v Clinton

# %% [markdown]
# Open debate_transcript.txt

# %%
with open('trump_hillary_debate.txt') as file:
    text = file.read()

# %% [markdown]
# Parse and filter the transcript

# %%
transcript = text.split('\n\n')

# %%
filtered_transcript = []
for para in transcript:
    if para.startswith('Trump:'):
        filtered_transcript.append((0,para[7:]))
    elif para.startswith('Clinton:'):
        filtered_transcript.append((1,para[9:]))

# %% [markdown]
# Import the module

# %%
import sys, os

# %%
package_path = os.path.dirname(os.getcwd())
sys.path.append(package_path)

# %%
from wordmesh import Wordmesh, LabelledWordmesh
# Out:
# Loading spaCy's language model...
# Done

# %% [markdown]
# Create a LabelledWordmesh object, and extract the **40 most frequently used *adjectives*** for each label

# %%
wm = LabelledWordmesh(filtered_transcript, dimensions=(500,900), num_keywords=40, extract_ngrams=False, 
                      keyword_extractor='tf', pos_filter=['ADJ'])

# %% [markdown]
# Cluster the extracted keywords on the canvas based on their **meaning**

# %%
wm.set_clustering_criteria(by='meaning')

# %% [markdown]
# Color the keywords based on their label and scores

# %%
# The following function maps the label and score of the keywords to their color
def colormap(label, score):
    if label==0:
        R,G,B = (150+100*score/22, 50+90*score/22, 50+90*score/22)
    elif label==1:
        R,G,B = (50+90*score/22, 50+90*score/22, 150+100*score/22)
    return (R,G,B)

#applying the mapping the wordmesh
wm.set_fontcolor(custom_colors = list(map(colormap, wm.labels, wm.scores)))

# %%
wm.plot()
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="809e3802-6536-4e6e-909c-55d6f38b7bdc" style="height: 500px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '809e3802-6536-4e6e-909c-55d6f38b7bdc',
#             [{"type": "scatter", "hoverinfo": "skip", "hovertext": null, "showlegend": false, "legendgroup": "default_legend", "name": "default_legend", "x": [89.13590206413514, 48.293737517596725, 48.331341590396434, 193.81308692535146, -197.39164835922793, 122.03767789840013, -65.89565779721278, 199.06627576168322, -21.377220966075555, 212.78939923231061, -39.21813701262492, 142.48647283525617, -51.56950856797444, 132.96568034561906, 177.09610498366445, -14.745943283461322, 4.246402286508811, -111.5554906903412, -8.945242654365522, 177.75014264990187, 6.884191802972865, -102.328023897599, -5.43706798166577, -34.38493494211231, 43.57011723913124, 211.63851612601837, 188.61432763151177, 91.08157487073912, -134.7034977428244, 83.42064543077035, 248.41193029499266, -92.66461419918132, 71.45045591716034, 255.9373652435543, 189.01961406893943, 117.48633524002716, 89.06397010499462, 120.40560241854452, -94.56123803910538, 220.64854569293635, 128.751343260831, -220.61283588219752, 67.34119014512575, 189.1222503398411, -14.098602971994552, 131.57141630778983, 66.94695137250346, -30.94555542581594, 43.21216461705333, 3.5781427939880963, -105.8814225094439, -51.